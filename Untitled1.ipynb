# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\HP\Documents\DM2025Labs\DM2025-Lab2-Exercise
# ['.git', '.gitattributes', '.gitignore', '.ipynb_checkpoints', '.python-version', '.venv', 'audios', 'config', 'data', 'DM2025-Lab2-Homework.ipynb', 'DM2025-Lab2-Master-Phase_1.ipynb', 'DM2025-Lab2-Master-Phase_2_Bonus.ipynb', 'DM2025-Lab2-Master-Phase_2_Main.ipynb', 'DM2025-Lab2-Optional-Ollama.ipynb', 'GoogleNews', 'instructions', 'LICENSE', 'logs', 'pics', 'pyproject.toml', 'README.md', 'requirements.txt', 'results', 'segmentation_outputs', 'Untitled.ipynb', 'Untitled1.ipynb', 'uv.lock', 'videos']

# %%
with open("config/.env", "w") as f:
    f.write('AIzaSyCJJOmCdQGRYVbgvEA2n7HLnlGpJs5zYcs"')

# %%
import os

# List files inside config folder
print(os.listdir("config"))
# Out:
# ['.env', '.ipynb_checkpoints', 'api_key_instructions.txt']

# %%
import os 
from dotenv import load_dotenv 
env_path = "./config/.env" 
load_dotenv(dotenv_path=env_path) 
api_key = os.getenv("GOOGLE_API_KEY") 
print(api_key)
# Out:
# None
