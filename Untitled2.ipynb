# %%
from dotenv import load_dotenv
import os

# Load the .env file
load_dotenv(dotenv_path="./config/.env")

# Access your API key
api_key = os.getenv("GOOGLE_API_KEY")
print(api_key)  # This should now print your key
# Out:
# AIzaSyCJJOmCdQGRYVbgvEA2n7HLnlGpJs5zYcs
